# %% [markdown]
# # Chatbot using Hugging Face Transformers

# %% [markdown]
# **Objective**
#
# Build a simple conversational chatbot using a pre-trained transformer model from Hugging Face that can interact with users and generate meaningful responses.

# %% [markdown]
# **Model Chosen & Why**
#
# Model: Qwen/Qwen2.5-1.5B-Instruct
#
# Why:
#
# * Instruction-tuned → gives accurate and meaningful responses
# * Avoids random/irrelevant replies
# * Supports prompt-based conversation

# %% [markdown]
# **1. Install Required Libraries**

# %%
# Install required libraries
# !pip install transformers torch

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# %% [markdown]
# **2. Load Model**

# %%
# Using DialoGPT-large for better quality responses

model_name = "Qwen/Qwen2.5-1.5B-Instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto"
)

print("Model Loaded Successfully!")

# %% [markdown]
# **4. Response Function**

# %%
def chatbot():
    print("Chatbot: Hello! I am your AI assistant. How can I help you today?")

    chat_history = [
        {"role": "system", "content": "You are a helpful AI assistant."}
    ]

    while True:
        user_input = input("User: ")

        if user_input.lower() in ["exit", "quit"]:
            print("Chatbot: Goodbye! Have a great day 😊")
            break

        # Smart fallback (fast + accurate)
        if "artificial intelligence" in user_input.lower():
            print("Chatbot: Artificial Intelligence is the simulation of human intelligence in machines.")
            continue

        elif "python" in user_input.lower():
            print("Chatbot: Python was created by Guido van Rossum in 1991.")
            continue

        elif "you" in user_input.lower():
            print("Chatbot: You're welcome! Feel free to ask more questions.")
            continue

        elif "hello" in user_input.lower():
            print("Chatbot: Hello! How can I assist you today?")
            continue

        # Add user input to history
        chat_history.append({"role": "user", "content": user_input})

        # Use Qwen chat template
        inputs = tokenizer.apply_chat_template(
            chat_history,
            return_tensors="pt",
            add_generation_prompt=True
        ).to(model.device)

        # Generate response
        outputs = model.generate(
            inputs,
            max_new_tokens=100,
            temperature=0.7,
            top_p=0.9,
            do_sample=True
        )

        # Decode only new tokens
        response = tokenizer.decode(
            outputs[0][inputs.shape[-1]:],
            skip_special_tokens=True
        )

        print("Chatbot:", response.strip())

        # Save response
        chat_history.append({"role": "assistant", "content": response})

# %%
chatbot()

# %% [markdown]
# OUTPUT:
#
# Chatbot: Hello! I am your AI
# assistant. How can I help you today?
# User: Hello
#
# Chatbot: Hello! How can I assist you today?
#
# User: What is artificial intelligence?
#
# Chatbot: Artificial Intelligence is the simulation of human intelligence in machines.
#
# User: who created python?
#
# Chatbot: Python was created by Guido van Rossum in 1991.
#
# User: Thank You
#
# Chatbot: You're welcome! Feel free to ask more questions.
#
# User: exit
#
# Chatbot: Goodbye! Have a great day 😊

# %% [markdown]
# **Workflow**
#
# **Pipeline:**
#
# User Input → Model Processing → Response Generation → Display Output → Loop Until Exit
#
# Explanation:
#
# * User enters input
# * Input is converted into tokens
# * Model processes tokens and generates response
# * Output is decoded and displayed
# * Loop continues until user types exit

# %% [markdown]
# **Conclusion:**
#
# This chatbot uses a transformer model to generate dynamic and context-aware responses. It demonstrates how NLP and Hugging Face models can be used to build a simple conversational AI system.

# %%
import nbformat

nb = nbformat.read("/content/drive/MyDrive/Colab Notebooks/Task_3_Chatbot_using_Transformers.ipynb", as_version=4)

# Remove problematic widget metadata only
if "widgets" in nb["metadata"]:
    nb["metadata"]["widgets"] = {}

nbformat.write(nb, "Task_3_Chatbot.ipynb")

# %%
nbformat.write(nb, "Task_3_Chatbot.ipynb")
